# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data=pd.read_excel("C:\\Users\\Dell\\Desktop\\data-analyst-data-set (1).xlsx")

# %%
#view entire data
data
# Out:
#        t  success        mid     pmt           pg               sub_type  \
# 0      2        1  MSD Dhoni      NB         PAYU                    NaN
# 1      1        0   VK Kholi      NB        PAYTM                    NaN
# 2      5        1   R Sharma  WALLET  AIRTELMONEY  REDIRECT_WALLET_DEBIT
# 3      1        1   R Sharma    CARD         PAYU                    NaN
# 4      1        1  Tendulkar    CARD     RAZORPAY                    NaN
# ...   ..      ...        ...     ...          ...                    ...
# 19302  1        1  Tendulkar    CARD     RAZORPAY                    NaN
# 19303  1        0  MSD Dhoni    CARD         HDFC                    NaN
# 19304  1        0    Ganguly    CARD   GOCASHFREE                    NaN
# 19305  1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 19306  1        1  MSD Dhoni    CARD         HDFC                    NaN
#
#                   hr                                 bank  success_rate %
# ...

# %%
#adding a new column for success rate
data['success_rate %']=round((data['success']*100)/data['t'],2)
data
# Out:
#        t  success        mid     pmt           pg               sub_type  \
# 0      2        1  MSD Dhoni      NB         PAYU                    NaN
# 1      1        0   VK Kholi      NB        PAYTM                    NaN
# 2      5        1   R Sharma  WALLET  AIRTELMONEY  REDIRECT_WALLET_DEBIT
# 3      1        1   R Sharma    CARD         PAYU                    NaN
# 4      1        1  Tendulkar    CARD     RAZORPAY                    NaN
# ...   ..      ...        ...     ...          ...                    ...
# 19302  1        1  Tendulkar    CARD     RAZORPAY                    NaN
# 19303  1        0  MSD Dhoni    CARD         HDFC                    NaN
# 19304  1        0    Ganguly    CARD   GOCASHFREE                    NaN
# 19305  1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 19306  1        1  MSD Dhoni    CARD         HDFC                    NaN
#
#                   hr                                 bank  success_rate %
# ...

# %%
#data sorted on the basis of Success Rate & Hour
d1=data.sort_values(['success_rate %','hr'],ascending=True)
d1
# Out:
#        t  success        mid     pmt           pg               sub_type  \
# 86     1        0      Singh      NB     RAZORPAY                    NaN
# 314    1        0   VK Kholi      NB        PAYTM                    NaN
# 647    1        0   R Sharma  WALLET  AIRTELMONEY  REDIRECT_WALLET_DEBIT
# 2736   1        0    Ganguly  WALLET     RAZORPAY  REDIRECT_WALLET_DEBIT
# 5644   1        0  Tendulkar      NB     RAZORPAY                    NaN
# ...   ..      ...        ...     ...          ...                    ...
# 14772  2        2      Singh  WALLET  OLAPOSTPAID  REDIRECT_WALLET_DEBIT
# 16444  1        1  MSD Dhoni    CARD         HDFC                    NaN
# 16530  1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 16966  1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 18849  1        1   R Sharma    CARD         PAYU                    NaN
#
#                   hr                     bank  success_rate %
# ...

# %%
#checking data information
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19307 entries, 86 to 18849
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   t               19307 non-null  int64
#  1   success         19307 non-null  int64
#  2   mid             19307 non-null  object
#  3   pmt             19307 non-null  object
#  4   pg              19270 non-null  object
#  5   sub_type        2903 non-null   object
#  6   hr              19307 non-null  object
#  7   bank            18969 non-null  object
#  8   success_rate %  19307 non-null  float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 1.5+ MB

# %%
#checking the overall stats of the data
d1.describe()
# Out:
#                   t       success  success_rate %
# count  19307.000000  19307.000000    19307.000000
# mean      11.730201      7.728492       66.308055
# std       53.396990     38.175935       37.329390
# min        1.000000      0.000000        0.000000
# 25%        1.000000      1.000000       47.060000
# 50%        2.000000      1.000000       76.000000
# 75%        6.000000      4.000000      100.000000
# max     3365.000000   2524.000000      100.000000

# %%
#unique columns
list(d1.columns)
# Out:
# ['t',
#  'success',
#  'mid',
#  'pmt',
#  'pg',
#  'sub_type',
#  'hr',
#  'bank',
#  'success_rate %']

# %%
#unique payment methods
list(d1['pmt'].unique())
# Out:
# ['NB', 'WALLET', 'CARD', 'CONSUMER_FINANCE', 'UPI']

# %%
#count of unique payment types
len(list(d1['pmt'].unique()))
# Out:
# 5

# %%
#unique payment gateways
d1['pg'].unique()
# Out:
# array(['RAZORPAY', 'PAYTM', 'AIRTELMONEY', 'PAYPAL', 'PAYU', 'MOBIKWIK',
#        'TPSL', 'GOCASHFREE', 'HDFC', 'ZAAKPAY', 'FSS_ATM_PIN_V2',
#        'EPAYLATER', nan, 'AMAZONPAY', 'OLAPOSTPAID', 'FREECHARGE', 'IPG',
#        'PHONEPE', 'PAYTM_V2', 'PAYTM_UPI'], dtype=object)

# %%
#count of unique payment gateways
len(d1['pg'].unique())
# Out:
# 20

# %%
#list of unique sub-types
list(d1['sub_type'].drop_duplicates())
# Out:
# [nan, 'REDIRECT_WALLET_DEBIT', 'DIRECT_WALLET_DEBIT', 'UPI_COLLECT', 'UPI_PAY']

# %%
#count of unique sub-types
len(list(d1['sub_type'].drop_duplicates()))
# Out:
# 5

# %%
#unique bank names
list(d1['bank'].drop_duplicates())
# Out:
# ['NB_SOIB',
#  'NB_OBC',
#  'AIRTELMONEY',
#  'NB_BOB',
#  'NB_SBI',
#  'PAYPAL',
#  'NB_AXIS',
#  'NB_HDFC',
#  'MOBIKWIK',
#  'NB_ICICI',
#  'NB_KOTAK',
#  'HDFC Bank',
#  'Canara Bank',
#  'Federal Bank',
#  'Allahabad Bank',
#  'Union Bank of India',
#  'NB_UNIB',
#  'SOUTHCAROLINAF.C.U.',
#  'Saraswat Bank',
#  'NB_SYNB',
#  'NB_IOB',
#  'BCCARDCO..LTD.',
#  'NB_AIRTEL',
#  'Airtel Payments Bank',
#  'AMEX',
#  'NB_BOI',
#  'NB_PNB',
#  'NB_UBI',
#  'NB_CANR',
#  'YES Bank',
#  'Bank of Baroda',
#  'Syndicate Bank',
#  'Kotak Mahindra Bank',
#  'NB_INDB',
#  'SARVA HARYANA GRAMIN BANK',
#  'INVESTMENTBANKVESTA(LLC)',
#  'MADHYA BIHAR GRAMIN BANK',
#  'NB_ANDHRA',
#  'DCB',
#  'NB_UCOB',
#  'Capital One Bank',
#  'NB_CORP',
#  'Kotak Bank',
#  'HIMACHAL PRADESH GRAMIN BANK',
#  'NB_CBI',
#  'NB_DENA',
#  nan,
#  'PAYTM',
#  'NB_IDBI',
#  'DBS Bank',
#  'IDBI Bank',
#  'Indian Bank',
#  'Corporation Bank',
#  'Central Bank of India',
#  'Jammu and Kashmir Bank',
# ...

# %%
#count of unique bank names
len(list(d1['bank'].drop_duplicates()))
# Out:
# 318

# %%
#Displaying unsuccessful transactions
d1[d1['success']==0]
# Out:
#        t  success        mid     pmt           pg               sub_type  \
# 86     1        0      Singh      NB     RAZORPAY                    NaN
# 314    1        0   VK Kholi      NB        PAYTM                    NaN
# 647    1        0   R Sharma  WALLET  AIRTELMONEY  REDIRECT_WALLET_DEBIT
# 2736   1        0    Ganguly  WALLET     RAZORPAY  REDIRECT_WALLET_DEBIT
# 5644   1        0  Tendulkar      NB     RAZORPAY                    NaN
# ...   ..      ...        ...     ...          ...                    ...
# 7442   3        0   VK Kholi      NB         PAYU                    NaN
# 9678   1        0   VK Kholi      NB        PAYTM                    NaN
# 10782  2        0    Ganguly  WALLET    AMAZONPAY                    NaN
# 11285  1        0   VK Kholi    CARD        PAYTM                    NaN
# 15745  1        0    Ganguly    CARD     RAZORPAY                    NaN
#
#                   hr           bank  success_rate %
# ...

# %%
#Plot of frequency of payment type when there is unsuccessful transaction
plt.bar(d1['pmt'][d1['success_rate %']==0].value_counts().keys(),d1['pmt'][d1['success_rate %']==0].value_counts().sort_values(ascending=False))
plt.xlabel('Payment Type',labelpad=10)
plt.ylabel('Frequency',labelpad=10)
plt.show()

# %%
#Total successful transactions
d1[d1['success']!=0]
# Out:
#         t  success        mid     pmt           pg               sub_type  \
# 3855   35        1   R Sharma     UPI     PAYTM_V2            UPI_COLLECT
# 4384   32        1   R Sharma     UPI     PAYTM_V2            UPI_COLLECT
# 4127   27        1   R Sharma     UPI     PAYTM_V2            UPI_COLLECT
# 6105   21        1  Tendulkar      NB     RAZORPAY                    NaN
# 6534   18        1  Tendulkar      NB     RAZORPAY                    NaN
# ...    ..      ...        ...     ...          ...                    ...
# 14772   2        2      Singh  WALLET  OLAPOSTPAID  REDIRECT_WALLET_DEBIT
# 16444   1        1  MSD Dhoni    CARD         HDFC                    NaN
# 16530   1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 16966   1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 18849   1        1   R Sharma    CARD         PAYU                    NaN
#
#                   hr                     bank  success_rate %
# ...

# %%
#viewing records where the success rate is less than 50%
d2=d1[d1['success_rate %']<50]
d2
# Out:
#         t  success        mid     pmt           pg               sub_type  \
# 86      1        0      Singh      NB     RAZORPAY                    NaN
# 314     1        0   VK Kholi      NB        PAYTM                    NaN
# 647     1        0   R Sharma  WALLET  AIRTELMONEY  REDIRECT_WALLET_DEBIT
# 2736    1        0    Ganguly  WALLET     RAZORPAY  REDIRECT_WALLET_DEBIT
# 5644    1        0  Tendulkar      NB     RAZORPAY                    NaN
# ...   ...      ...        ...     ...          ...                    ...
# 4411   53       26  Tendulkar     UPI    PAYTM_UPI                UPI_PAY
# 6930   55       27   R Sharma  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 8589   85       42   R Sharma  WALLET      PHONEPE  REDIRECT_WALLET_DEBIT
# 7031   89       44   VK Kholi  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 4441  422      209   VK Kholi     UPI     PAYTM_V2                UPI_PAY
#
#                  hr         bank  success_rate %
# ...

# %%
#top 10 successful transactions
d1[d1['success']!=0].nlargest(10,columns='success_rate %')
# Out:
#       t  success         mid   pmt          pg sub_type             hr  \
# 532   1        1  Ravi Jaddu  CARD       PAYTM      NaN  2020-02-12 00
# 927   1        1    R Sharma  CARD        PAYU      NaN  2020-02-12 00
# 1287  1        1    R Sharma  CARD        PAYU      NaN  2020-02-12 00
# 1379  1        1       Rahul    NB        PAYU      NaN  2020-02-12 00
# 2846  1        1       Singh  CARD        TPSL      NaN  2020-02-12 00
# 2960  1        1   Tendulkar  CARD  GOCASHFREE      NaN  2020-02-12 00
# 2981  1        1    R Sharma  CARD        PAYU      NaN  2020-02-12 00
# 3388  2        2    VK Kholi  CARD       PAYTM      NaN  2020-02-12 00
# 3395  1        1     Ganguly  CARD  GOCASHFREE      NaN  2020-02-12 00
# 3557  1        1  Ravi Jaddu  CARD       PAYTM      NaN  2020-02-12 00
#
#                                      bank  success_rate %
# 532                     South Indian Bank           100.0
# 927   The Shamrao Vithal Cooperative Bank           100.0
# ...

# %%
#total unique success values
len(d1['success'].drop_duplicates())
# Out:
# 232

# %%
#Plot for frequency of successful transations
plt.figure(figsize=(8,6))
plt.bar(list(d1['success'][d1['success']!=0].value_counts()[0:10].keys()),list(d1['success'][d1['success']!=0].value_counts()[0:10]))
plt.show()

# %%
#Line Plot for frequency of top 10 successful transations
plt.figure(figsize=(14,6))
plt.plot(list(d1['success'][d1['success']!=0].value_counts().sort_values(ascending=False).keys()[0:10]),list(d1['success'][d1['success']!=0].value_counts().sort_values(ascending=False)[0:10]))
plt.xlabel('Success',labelpad=10)
plt.ylabel('Frequency',labelpad=10)
plt.show()

# %%
#top 10 successful and unsuccessful transactions
a1=d1['success'].value_counts()[0:10].sort_values(ascending=True)

# %%
#Plot for frequency of top 10 successful & unsuccessful transations
plt.figure(figsize=(14,6))
plt.bar(list(a1.keys()),list(a1),color='purple')
plt.xlabel('Success',labelpad=10)
plt.ylabel('Frequency',labelpad=10)
plt.show()

# %%
#List of unique merchants
d1['mid'].drop_duplicates()
# Out:
# 86            Singh
# 314        VK Kholi
# 647        R Sharma
# 2736        Ganguly
# 5644      Tendulkar
# 6865      MSD Dhoni
# 8053     Ravi Jaddu
# 12512         Rahul
# Name: mid, dtype: object

# %%
#total unique merchants
len(list(d1['mid'].drop_duplicates()))
# Out:
# 8

# %%
#checking & displaying top 20 records where the success rate is less than 50%
d3=d2.nlargest(20,columns='success_rate %')
d3
# Out:
#          t  success         mid     pmt           pg               sub_type  \
# 4441   422      209    VK Kholi     UPI     PAYTM_V2                UPI_PAY
# 7031    89       44    VK Kholi  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 8589    85       42    R Sharma  WALLET      PHONEPE  REDIRECT_WALLET_DEBIT
# 6930    55       27    R Sharma  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 4411    53       26   Tendulkar     UPI    PAYTM_UPI                UPI_PAY
# 7729    45       22    VK Kholi      NB        PAYTM                    NaN
# 8976    43       21   Tendulkar  WALLET     MOBIKWIK    DIRECT_WALLET_DEBIT
# 7063    84       41    R Sharma  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 3994    82       40  Ravi Jaddu     UPI         PAYU                UPI_PAY
# 7054    78       38    VK Kholi  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 7072    78       38    VK Kholi  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# ...

# %%
#frequency of payment type in top 20 records
d3['pmt'].value_counts().sort_values(ascending=False)
# Out:
# WALLET    15
# UPI        3
# NB         2
# Name: pmt, dtype: int64

# %%
#total records when success rate is 0 and payment type is WALLET
d1[(d1['pmt']=='WALLET') & (d1['success_rate %']==0)]
# Out:
#        t  success         mid     pmt           pg               sub_type  \
# 647    1        0    R Sharma  WALLET  AIRTELMONEY  REDIRECT_WALLET_DEBIT
# 2736   1        0     Ganguly  WALLET     RAZORPAY  REDIRECT_WALLET_DEBIT
# 6865   1        0   MSD Dhoni  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 8820   1        0    R Sharma  WALLET     MOBIKWIK  REDIRECT_WALLET_DEBIT
# 8940   2        0   MSD Dhoni  WALLET     MOBIKWIK    DIRECT_WALLET_DEBIT
# ...   ..      ...         ...     ...          ...                    ...
# 14819  1        0  Ravi Jaddu  WALLET  OLAPOSTPAID  REDIRECT_WALLET_DEBIT
# 5380   1        0     Ganguly  WALLET        PAYTM  REDIRECT_WALLET_DEBIT
# 6781   4        0       Singh  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 6975   1        0    R Sharma  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 10782  2        0     Ganguly  WALLET    AMAZONPAY                    NaN
#
#                   hr         bank  success_rate %
# ...

# %%
#total records when success rate is 0 and payment type is CARD
d1[(d1['pmt']=='CARD') & (d1['success_rate %']==0)]
# Out:
#        t  success        mid   pmt          pg sub_type             hr  \
# 12512  1        0      Rahul  CARD        PAYU      NaN  2020-02-12 00
# 14331  2        0   R Sharma  CARD        PAYU      NaN  2020-02-12 00
# 15032  2        0   VK Kholi  CARD       PAYTM      NaN  2020-02-12 00
# 15899  1        0      Singh  CARD        TPSL      NaN  2020-02-12 00
# 17709  1        0   R Sharma  CARD        PAYU      NaN  2020-02-12 00
# ...   ..      ...        ...   ...         ...      ...            ...
# 19183  1        0  MSD Dhoni  CARD        PAYU      NaN  2020-02-14 21
# 12712  1        0  MSD Dhoni  CARD    RAZORPAY      NaN  2020-02-14 22
# 16105  1        0  Tendulkar  CARD  GOCASHFREE      NaN  2020-02-14 22
# 11285  1        0   VK Kholi  CARD       PAYTM      NaN  2020-02-14 23
# 15745  1        0    Ganguly  CARD    RAZORPAY      NaN  2020-02-14 23
#
#                             bank  success_rate %
# 12512                  HDFC Bank             0.0
# ...

# %%
#total records when success rate is 0 and payment type is UPI
d1[(d1['pmt']=='UPI') & (d1['success_rate %']==0)]
# Out:
#        t  success         mid  pmt        pg     sub_type             hr  \
# 322    1        0    R Sharma  UPI       NaN  UPI_COLLECT  2020-02-12 09
# 11443  1        0    R Sharma  UPI      PAYU  UPI_COLLECT  2020-02-12 14
# 3958   2        0    VK Kholi  UPI  PAYTM_V2  UPI_COLLECT  2020-02-12 22
# 4578   3        0  Ravi Jaddu  UPI  PAYTM_V2  UPI_COLLECT  2020-02-12 22
# 4342   1        0   Tendulkar  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 02
# 4078   2        0    R Sharma  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 19
# 4334   4        0       Singh  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 20
# 4063   4        0    R Sharma  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 21
# 4084   1        0       Singh  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 21
# 4563   2        0    VK Kholi  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 21
# 4048   2        0       Rahul  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 22
# 4083   3        0       Singh  UPI  PAYTM_V2  UPI_COLLECT  2020-02-13 22
# ...

# %%
#total records when success rate is 0 and payment type is UPI
len(d1[(d1['pmt']=='UPI') & (d1['success_rate %']==0)])
# Out:
# 27

# %%
#total records when success rate is 0 and payment type is NB
d1[(d1['pmt']=='NB') & (d1['success_rate %']==0)]
# Out:
#       t  success        mid pmt        pg sub_type             hr      bank  \
# 86    1        0      Singh  NB  RAZORPAY      NaN  2020-02-12 00   NB_SOIB
# 314   1        0   VK Kholi  NB     PAYTM      NaN  2020-02-12 00    NB_OBC
# 5644  1        0  Tendulkar  NB  RAZORPAY      NaN  2020-02-12 00    NB_BOB
# 6199  1        0   R Sharma  NB     PAYTM      NaN  2020-02-12 00    NB_SBI
# 6589  1        0   VK Kholi  NB     PAYTM      NaN  2020-02-12 00    NB_SBI
# ...  ..      ...        ...  ..       ...      ...            ...       ...
# 6136  4        0  Tendulkar  NB  RAZORPAY      NaN  2020-02-14 23    NB_SBI
# 6539  1        0      Singh  NB  RAZORPAY      NaN  2020-02-14 23    NB_SBI
# 6623  1        0  MSD Dhoni  NB      PAYU      NaN  2020-02-14 23    NB_SBI
# 7442  3        0   VK Kholi  NB      PAYU      NaN  2020-02-14 23   NB_AXIS
# 9678  1        0   VK Kholi  NB     PAYTM      NaN  2020-02-14 23  NB_KOTAK
#
#       success_rate %
# 86               0.0
# ...

# %%
#total records when success rate is 0 and payment type is CONSUMER_FINANCE
d1[(d1['pmt']=='CONSUMER_FINANCE') & (d1['success_rate %']==0)]
# Out:
#       t  success         mid               pmt         pg sub_type  \
# 426   1        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 2179  5        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 103   3        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 1995  2        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 331   2        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 2119  3        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 748   1        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 745   1        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 2399  3        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 499   2        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 1359  1        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 601   2        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# 2504  1        0     Ganguly  CONSUMER_FINANCE  EPAYLATER      NaN
# ...

# %%
#total records when success rate is 0 and payment type is UPI
len(d1[(d1['pmt']=='CONSUMER_FINANCE') & (d1['success_rate %']==0)])
# Out:
# 22

# %%
#Histogram for records where success rate is less than 50%
plt.figure(figsize=(8,4))
plt.hist(list(d2['pmt']))
plt.xlabel('Payment Type',labelpad=10)
plt.ylabel('Frequency',labelpad=10)
plt.show()

# %%
#viewing records where the success rate is more than 50%
d4=d1[d1['success_rate %']>50]
d4
# Out:
#          t  success        mid     pmt           pg               sub_type  \
# 8625   159       80   R Sharma  WALLET      PHONEPE  REDIRECT_WALLET_DEBIT
# 6878   113       57   R Sharma  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 8481   202      102   R Sharma  WALLET      PHONEPE  REDIRECT_WALLET_DEBIT
# 7028    99       50   VK Kholi  WALLET       PAYPAL  REDIRECT_WALLET_DEBIT
# 7881    97       49   VK Kholi      NB        PAYTM                    NaN
# ...    ...      ...        ...     ...          ...                    ...
# 14772    2        2      Singh  WALLET  OLAPOSTPAID  REDIRECT_WALLET_DEBIT
# 16444    1        1  MSD Dhoni    CARD         HDFC                    NaN
# 16530    1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 16966    1        1    Ganguly    CARD   GOCASHFREE                    NaN
# 18849    1        1   R Sharma    CARD         PAYU                    NaN
#
#                   hr                     bank  success_rate %
# ...

# %%
d2[['pg','pmt','success_rate %','sub_type']]
# Out:
#                pg     pmt  success_rate %               sub_type
# 86       RAZORPAY      NB            0.00                    NaN
# 314         PAYTM      NB            0.00                    NaN
# 647   AIRTELMONEY  WALLET            0.00  REDIRECT_WALLET_DEBIT
# 2736     RAZORPAY  WALLET            0.00  REDIRECT_WALLET_DEBIT
# 5644     RAZORPAY      NB            0.00                    NaN
# ...           ...     ...             ...                    ...
# 4411    PAYTM_UPI     UPI           49.06                UPI_PAY
# 6930       PAYPAL  WALLET           49.09  REDIRECT_WALLET_DEBIT
# 8589      PHONEPE  WALLET           49.41  REDIRECT_WALLET_DEBIT
# 7031       PAYPAL  WALLET           49.44  REDIRECT_WALLET_DEBIT
# 4441     PAYTM_V2     UPI           49.53                UPI_PAY
#
# [4905 rows x 4 columns]

# %%
d2['pg'].value_counts()[0:5]
# Out:
# RAZORPAY      1161
# PAYU          1101
# PAYTM          932
# GOCASHFREE     631
# TPSL           242
# Name: pg, dtype: int64

# %%
#Plot for top 5 payment gatewyas when success rate <50%
plt.figure(figsize=(8,6))
plt.bar(list(d2['pg'].value_counts()[0:5].keys()),list(d2['pg'].value_counts()[0:5]),color=['purple','red','yellow','blue','orange'])
plt.xlabel('Payment Gateway',labelpad=10)
plt.ylabel('Frequency',labelpad=10)
plt.show()

# %%
#unique hr values
len(list(d1['hr'].drop_duplicates()))
# Out:
# 72

# %%
#top 5 payment gateways when the success rate is 0
d5=d1['pg'][d1['success_rate %']==0].value_counts()[0:5].sort_values(ascending=False)
d5
# Out:
# RAZORPAY      915
# PAYU          865
# PAYTM         703
# GOCASHFREE    444
# TPSL          174
# Name: pg, dtype: int64

# %%
#Plot for top 5 payment gateways when the success rate is 0
plt.figure(figsize=(8,6))
plt.bar(list(d5.keys()),list(d5),color=['green','orange','blue','red','brown'])
plt.xlabel('Payment Gateway',labelpad=10)
plt.ylabel('Frequency',labelpad=10)
plt.show()
